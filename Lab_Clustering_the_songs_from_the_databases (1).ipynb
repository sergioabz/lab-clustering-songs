# %% [markdown]
# # Dimensionality reduction

# %%
#importing libraries
from random import randint
import time
from time import sleep
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import numpy as np
import pandas as pd

# %%
#Sklearn
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import euclidean
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from kneed import KneeLocator
import matplotlib.pyplot as plt
import seaborn as sns
import colorcet as cc
import time
import pickle

# %% [markdown]
# ### Read .csv and cleand

# %%
read_hs = pd.read_csv('hot_songs_features.csv')
read_nhs = pd.read_csv('not_hot_songs_features.csv')

# %%
read_hs1 = read_hs.copy()
read_nhs1 = read_nhs.copy()

# %%
drop_hs = read_hs1.drop([99])

# %%
drop_hs.tail()
# Out:
#                   Title          Artist  danceability  energy  key  loudness  \
# 94  East Side Of Sorrow      Zach Bryan         0.475   0.789  1.0    -6.124
# 95   Standing Room Only      Tim McGraw         0.731   0.622  5.0    -8.237
# 96            Checkmate        Rod Wave         0.663   0.502  5.0    -7.070
# 97      Can't Have Mine     Dylan Scott         0.481   0.539  4.0    -7.865
# 98           On My Mama  Victoria Monet         0.534   0.820  9.0    -3.440
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 94   1.0       0.0380       0.17000           0.00000     0.147    0.485
# 95   1.0       0.0979       0.17600           0.00000     0.153    0.445
# 96   1.0       0.0285       0.79100           0.00000     0.105    0.371
# 97   0.0       0.1080       0.55100           0.00539     0.120    0.621
# 98   1.0       0.0886       0.00376           0.00000     0.136    0.664
#
#       tempo            type                      id  \
# 94  155.227  audio_features  6BOP0cv1eeXcvi1oE8bDVZ
# 95   82.494  audio_features  6VdBDm20nkyk6A29P785aJ
# 96  143.969  audio_features  3jfywRZH6cB2iLyKqo4EZd
# 97  153.277  audio_features  1o8Z7GD1CeOaVBEyuzu4HO
# 98  160.064  audio_features  1haoEnXbsUS3OFIWaUJ3wb
#
#                                      uri  \
# 94  spotify:track:6BOP0cv1eeXcvi1oE8bDVZ
# 95  spotify:track:6VdBDm20nkyk6A29P785aJ
# 96  spotify:track:3jfywRZH6cB2iLyKqo4EZd
# 97  spotify:track:1o8Z7GD1CeOaVBEyuzu4HO
# 98  spotify:track:1haoEnXbsUS3OFIWaUJ3wb
#
#                                            track_href  \
# 94  https://api.spotify.com/v1/tracks/6BOP0cv1eeXc...
# 95  https://api.spotify.com/v1/tracks/6VdBDm20nkyk...
# 96  https://api.spotify.com/v1/tracks/3jfywRZH6cB2...
# 97  https://api.spotify.com/v1/tracks/1o8Z7GD1CeOa...
# 98  https://api.spotify.com/v1/tracks/1haoEnXbsUS3...
#
#                                          analysis_url  duration_ms  \
# 94  https://api.spotify.com/v1/audio-analysis/6BOP...     226091.0
# 95  https://api.spotify.com/v1/audio-analysis/6VdB...     198034.0
# 96  https://api.spotify.com/v1/audio-analysis/3jfy...     183087.0
# 97  https://api.spotify.com/v1/audio-analysis/1o8Z...     186678.0
# 98  https://api.spotify.com/v1/audio-analysis/1hao...     154517.0
#
#     time_signature
# 94             4.0
# 95             4.0
# 96             4.0
# 97             4.0
# 98             4.0

# %%
drop_nhs = read_nhs1.drop([2294,2295,2296,2297])

# %%
drop_nhs.tail()
# Out:
#                   Title           Artist  danceability  energy   key  \
# 2289         La Bachata    Manuel Turizo         0.775   0.736   1.0
# 2290  Until I Found You  Stephen Sanchez         0.935   0.807  11.0
# 2291      Made You Look   Meghan Trainor         0.751   0.468   5.0
# 2292      Midnight Rain     Taylor Swift         0.773   0.422   1.0
# 2293           Die Hard   Kendrick Lamar         0.376   0.657   7.0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 2289    -8.072   0.0       0.2470       0.31900          0.001160    0.1270
# 2290    -3.838   0.0       0.1140       0.05140          0.000000    0.3490
# 2291    -9.251   1.0       0.3130       0.15000          0.000015    0.1920
# 2292    -4.572   0.0       0.1870       0.00783          0.006930    0.1290
# 2293    -4.658   1.0       0.0768       0.08580          0.000000    0.0884
#
#       valence    tempo            type                      id  \
# 2289    0.362  100.988  audio_features  2g6tReTlM2Akp41g0HaeXN
# 2290    0.813  106.017  audio_features  6Zu3aw7FfjAF9WA0fA81Oq
# 2291    0.214  150.009  audio_features  1DlLCrqbalAshwtMexNkGR
# 2292    0.488   77.502  audio_features  3XOalgusokruzA5ZBA2Qcb
# 2293    0.203   80.565  audio_features  1r8ZCjfrQxoy2wVaBUbpwg
#
#                                        uri  \
# 2289  spotify:track:2g6tReTlM2Akp41g0HaeXN
# 2290  spotify:track:6Zu3aw7FfjAF9WA0fA81Oq
# 2291  spotify:track:1DlLCrqbalAshwtMexNkGR
# 2292  spotify:track:3XOalgusokruzA5ZBA2Qcb
# 2293  spotify:track:1r8ZCjfrQxoy2wVaBUbpwg
#
#                                              track_href  \
# 2289  https://api.spotify.com/v1/tracks/2g6tReTlM2Ak...
# 2290  https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF...
# 2291  https://api.spotify.com/v1/tracks/1DlLCrqbalAs...
# 2292  https://api.spotify.com/v1/tracks/3XOalgusokru...
# 2293  https://api.spotify.com/v1/tracks/1r8ZCjfrQxoy...
#
#                                            analysis_url  duration_ms  \
# 2289  https://api.spotify.com/v1/audio-analysis/2g6t...     239027.0
# 2290  https://api.spotify.com/v1/audio-analysis/6Zu3...     173182.0
# 2291  https://api.spotify.com/v1/audio-analysis/1DlL...     184842.0
# 2292  https://api.spotify.com/v1/audio-analysis/3XOa...     136267.0
# 2293  https://api.spotify.com/v1/audio-analysis/1r8Z...     164782.0
#
#       time_signature
# 2289             4.0
# 2290             4.0
# 2291             4.0
# 2292             1.0
# 2293             4.0

# %%
#Save the final dataframes
drop_hs.to_csv("hot_songs_features_final.csv", index=False)
drop_nhs.to_csv("not_hot_songs_features_final.csv", index=False)

# %% [markdown]
# ### Hot or not_hot songs (Y/N)

# %%
#Read df

hot_songs_features = pd.read_csv('hot_songs_features_final.csv')
not_hot_songs_features = pd.read_csv('not_hot_songs_features_final.csv')

# %%
# hot_song_features["Hot"] = "Y"
# not_hot_songs["Hot"] = "N"

# %%
hot_songs_features["Hot"] = "Y"
hot_songs_features
# Out:
#                     Title                                Artist  danceability  \
# 0      Paint The Town Red                              Doja Cat         0.864
# 1                  Snooze                                   SZA         0.559
# 2                Fast Car                            Luke Combs         0.551
# 3            Cruel Summer                          Taylor Swift         0.666
# 4   I Remember Everything  Zach Bryan Featuring Kacey Musgraves         0.429
# ..                    ...                                   ...           ...
# 94    East Side Of Sorrow                            Zach Bryan         0.475
# 95     Standing Room Only                            Tim McGraw         0.731
# 96              Checkmate                              Rod Wave         0.663
# 97        Can't Have Mine                           Dylan Scott         0.481
# 98             On My Mama                        Victoria Monet         0.534
#
#     energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0    0.556  2.0    -7.683   0.0       0.1940       0.25500          0.000004
# 1    0.551  5.0    -7.231   1.0       0.1320       0.14100          0.000000
# 2    0.801  6.0    -5.069   1.0       0.0303       0.01300          0.000006
# 3    0.871  1.0    -6.017   0.0       0.0272       0.27000          0.020800
# 4    0.453  0.0    -7.746   1.0       0.0459       0.55400          0.000002
# ..     ...  ...       ...   ...          ...           ...               ...
# 94   0.789  1.0    -6.124   1.0       0.0380       0.17000          0.000000
# 95   0.622  5.0    -8.237   1.0       0.0979       0.17600          0.000000
# 96   0.502  5.0    -7.070   1.0       0.0285       0.79100          0.000000
# 97   0.539  4.0    -7.865   0.0       0.1080       0.55100          0.005390
# 98   0.820  9.0    -3.440   1.0       0.0886       0.00376          0.000000
#
#     ...  valence    tempo            type                      id  \
# 0   ...    0.726   99.974  audio_features  56y1jOTK0XSvJzVv9vHQBK
# 1   ...    0.392  143.008  audio_features  4iZ4pt7kvcaH6Yo8UoZ4s2
# 2   ...    0.625  128.027  audio_features  1mMLMZYXkMueg65jRRWG1l
# 3   ...    0.936  108.501  audio_features  2EGaDf0cPX789H3LNeB03D
# 4   ...    0.155   77.639  audio_features  4KULAymBBJcPRpk1yO4dOG
# ..  ...      ...      ...             ...                     ...
# 94  ...    0.485  155.227  audio_features  6BOP0cv1eeXcvi1oE8bDVZ
# 95  ...    0.445   82.494  audio_features  6VdBDm20nkyk6A29P785aJ
# 96  ...    0.371  143.969  audio_features  3jfywRZH6cB2iLyKqo4EZd
# 97  ...    0.621  153.277  audio_features  1o8Z7GD1CeOaVBEyuzu4HO
# 98  ...    0.664  160.064  audio_features  1haoEnXbsUS3OFIWaUJ3wb
#
#                                      uri  \
# 0   spotify:track:56y1jOTK0XSvJzVv9vHQBK
# 1   spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 2   spotify:track:1mMLMZYXkMueg65jRRWG1l
# 3   spotify:track:2EGaDf0cPX789H3LNeB03D
# 4   spotify:track:4KULAymBBJcPRpk1yO4dOG
# ..                                   ...
# 94  spotify:track:6BOP0cv1eeXcvi1oE8bDVZ
# 95  spotify:track:6VdBDm20nkyk6A29P785aJ
# 96  spotify:track:3jfywRZH6cB2iLyKqo4EZd
# 97  spotify:track:1o8Z7GD1CeOaVBEyuzu4HO
# 98  spotify:track:1haoEnXbsUS3OFIWaUJ3wb
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/56y1jOTK0XSv...
# 1   https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 2   https://api.spotify.com/v1/tracks/1mMLMZYXkMue...
# 3   https://api.spotify.com/v1/tracks/2EGaDf0cPX78...
# 4   https://api.spotify.com/v1/tracks/4KULAymBBJcP...
# ..                                                ...
# 94  https://api.spotify.com/v1/tracks/6BOP0cv1eeXc...
# 95  https://api.spotify.com/v1/tracks/6VdBDm20nkyk...
# 96  https://api.spotify.com/v1/tracks/3jfywRZH6cB2...
# 97  https://api.spotify.com/v1/tracks/1o8Z7GD1CeOa...
# 98  https://api.spotify.com/v1/tracks/1haoEnXbsUS3...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/56y1...    230480.0
# 1   https://api.spotify.com/v1/audio-analysis/4iZ4...    201800.0
# 2   https://api.spotify.com/v1/audio-analysis/1mML...    240760.0
# 3   https://api.spotify.com/v1/audio-analysis/2EGa...    215326.0
# 4   https://api.spotify.com/v1/audio-analysis/4KUL...    227196.0
# ..                                                ...         ...
# 94  https://api.spotify.com/v1/audio-analysis/6BOP...    226091.0
# 95  https://api.spotify.com/v1/audio-analysis/6VdB...    198034.0
# 96  https://api.spotify.com/v1/audio-analysis/3jfy...    183087.0
# 97  https://api.spotify.com/v1/audio-analysis/1o8Z...    186678.0
# 98  https://api.spotify.com/v1/audio-analysis/1hao...    154517.0
#
#     time_signature  Hot
# 0              4.0    Y
# 1              4.0    Y
# 2              4.0    Y
# 3              4.0    Y
# 4              4.0    Y
# ..             ...  ...
# 94             4.0    Y
# 95             4.0    Y
# 96             4.0    Y
# 97             4.0    Y
# 98             4.0    Y
#
# [99 rows x 21 columns]

# %%
not_hot_songs_features["Hot"] = "N"
not_hot_songs_features
# Out:
#                      Title           Artist  danceability  energy   key  \
# 0                   Yellow         Coldplay         0.429   0.661  11.0
# 1     All The Small Things        blink-182         0.434   0.897   0.0
# 2                  Breathe       Faith Hill         0.529   0.496   7.0
# 3               In the End      Linkin Park         0.556   0.864   3.0
# 4              Bye Bye Bye           *NSYNC         0.610   0.926   8.0
# ...                    ...              ...           ...     ...   ...
# 2289            La Bachata    Manuel Turizo         0.775   0.736   1.0
# 2290     Until I Found You  Stephen Sanchez         0.935   0.807  11.0
# 2291         Made You Look   Meghan Trainor         0.751   0.468   5.0
# 2292         Midnight Rain     Taylor Swift         0.773   0.422   1.0
# 2293              Die Hard   Kendrick Lamar         0.376   0.657   7.0
#
#       loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0       -7.227   1.0       0.0281       0.00239          0.000121  ...
# 1       -4.918   1.0       0.0488       0.01030          0.000000  ...
# 2       -9.007   1.0       0.0290       0.17300          0.000000  ...
# 3       -5.870   0.0       0.0584       0.00958          0.000000  ...
# 4       -4.843   0.0       0.0479       0.03100          0.001200  ...
# ...        ...   ...          ...           ...               ...  ...
# 2289    -8.072   0.0       0.2470       0.31900          0.001160  ...
# 2290    -3.838   0.0       0.1140       0.05140          0.000000  ...
# 2291    -9.251   1.0       0.3130       0.15000          0.000015  ...
# 2292    -4.572   0.0       0.1870       0.00783          0.006930  ...
# 2293    -4.658   1.0       0.0768       0.08580          0.000000  ...
#
#       valence    tempo            type                      id  \
# 0       0.285  173.372  audio_features  3AJwUDP919kvQ9QcozQPxg
# 1       0.684  148.726  audio_features  2m1hi0nfMR9vdGC8UcrnwU
# 2       0.278  136.859  audio_features  3y4LxiYMgDl4RethdzpmNe
# 3       0.400  105.143  audio_features  60a0Rd6pjrkxjPbaKzXjfq
# 4       0.861  172.638  audio_features  62bOmKYxYg7dhrC6gH9vFn
# ...       ...      ...             ...                     ...
# 2289    0.362  100.988  audio_features  2g6tReTlM2Akp41g0HaeXN
# 2290    0.813  106.017  audio_features  6Zu3aw7FfjAF9WA0fA81Oq
# 2291    0.214  150.009  audio_features  1DlLCrqbalAshwtMexNkGR
# 2292    0.488   77.502  audio_features  3XOalgusokruzA5ZBA2Qcb
# 2293    0.203   80.565  audio_features  1r8ZCjfrQxoy2wVaBUbpwg
#
#                                        uri  \
# 0     spotify:track:3AJwUDP919kvQ9QcozQPxg
# 1     spotify:track:2m1hi0nfMR9vdGC8UcrnwU
# 2     spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3     spotify:track:60a0Rd6pjrkxjPbaKzXjfq
# 4     spotify:track:62bOmKYxYg7dhrC6gH9vFn
# ...                                    ...
# 2289  spotify:track:2g6tReTlM2Akp41g0HaeXN
# 2290  spotify:track:6Zu3aw7FfjAF9WA0fA81Oq
# 2291  spotify:track:1DlLCrqbalAshwtMexNkGR
# 2292  spotify:track:3XOalgusokruzA5ZBA2Qcb
# 2293  spotify:track:1r8ZCjfrQxoy2wVaBUbpwg
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/3AJwUDP919kv...
# 1     https://api.spotify.com/v1/tracks/2m1hi0nfMR9v...
# 2     https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3     https://api.spotify.com/v1/tracks/60a0Rd6pjrkx...
# 4     https://api.spotify.com/v1/tracks/62bOmKYxYg7d...
# ...                                                 ...
# 2289  https://api.spotify.com/v1/tracks/2g6tReTlM2Ak...
# 2290  https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF...
# 2291  https://api.spotify.com/v1/tracks/1DlLCrqbalAs...
# 2292  https://api.spotify.com/v1/tracks/3XOalgusokru...
# 2293  https://api.spotify.com/v1/tracks/1r8ZCjfrQxoy...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/3AJw...    266773.0
# 1     https://api.spotify.com/v1/audio-analysis/2m1h...    167067.0
# 2     https://api.spotify.com/v1/audio-analysis/3y4L...    250547.0
# 3     https://api.spotify.com/v1/audio-analysis/60a0...    216880.0
# 4     https://api.spotify.com/v1/audio-analysis/62bO...    200400.0
# ...                                                 ...         ...
# 2289  https://api.spotify.com/v1/audio-analysis/2g6t...    239027.0
# 2290  https://api.spotify.com/v1/audio-analysis/6Zu3...    173182.0
# 2291  https://api.spotify.com/v1/audio-analysis/1DlL...    184842.0
# 2292  https://api.spotify.com/v1/audio-analysis/3XOa...    136267.0
# 2293  https://api.spotify.com/v1/audio-analysis/1r8Z...    164782.0
#
#       time_signature  Hot
# 0                4.0    N
# 1                4.0    N
# 2                4.0    N
# 3                4.0    N
# 4                4.0    N
# ...              ...  ...
# 2289             4.0    N
# 2290             4.0    N
# 2291             4.0    N
# 2292             1.0    N
# 2293             4.0    N
#
# [2294 rows x 21 columns]

# %% [markdown]
# _____

# %% [markdown]
# ## Concat DataFrame

# %%
concat_nhs_hs = pd.concat([hot_songs_features, not_hot_songs_features], axis=0) 
concat_nhs_hs.head(1)
# Out:
#                 Title    Artist  danceability  energy  key  loudness  mode  \
# 0  Paint The Town Red  Doja Cat         0.864   0.556  2.0    -7.683   0.0
#
#    speechiness  acousticness  instrumentalness  ...  valence   tempo  \
# 0        0.194         0.255          0.000004  ...    0.726  99.974
#
#              type                      id  \
# 0  audio_features  56y1jOTK0XSvJzVv9vHQBK
#
#                                     uri  \
# 0  spotify:track:56y1jOTK0XSvJzVv9vHQBK
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/56y1jOTK0XSv...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/56y1...    230480.0
#
#    time_signature  Hot
# 0             4.0    Y
#
# [1 rows x 21 columns]

# %%
#Save the final dataframe hot_songs+ids+audio_features
#hot_songs_features.to_csv("hot_songs_features.csv", index=False)

# %%
concat_nhs_hs.shape
# Out:
# (2393, 21)

# %%
concat_nhs_hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2393 entries, 0 to 2293
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             2393 non-null   object
#  1   Artist            2393 non-null   object
#  2   danceability      2393 non-null   float64
#  3   energy            2393 non-null   float64
#  4   key               2393 non-null   float64
#  5   loudness          2393 non-null   float64
#  6   mode              2393 non-null   float64
#  7   speechiness       2393 non-null   float64
#  8   acousticness      2393 non-null   float64
#  9   instrumentalness  2393 non-null   float64
#  10  liveness          2393 non-null   float64
#  11  valence           2393 non-null   float64
#  12  tempo             2393 non-null   float64
#  13  type              2393 non-null   object
#  14  id                2393 non-null   object
#  15  uri               2393 non-null   object
#  16  track_href        2393 non-null   object
#  17  analysis_url      2393 non-null   object
#  18  duration_ms       2393 non-null   float64
#  19  time_signature    2393 non-null   float64
#  20  Hot               2393 non-null   object
# dtypes: float64(13), object(8)
# memory usage: 411.3+ KB

# %%
features = concat_nhs_hs.iloc[:, list(range(2, 13)) + list(range(18, 20))].copy()
features.head(50)
# Out:
#     danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0          0.864  0.5560   2.0    -7.683   0.0       0.1940      0.255000
# 1          0.559  0.5510   5.0    -7.231   1.0       0.1320      0.141000
# 2          0.551  0.8010   6.0    -5.069   1.0       0.0303      0.013000
# 3          0.666  0.8710   1.0    -6.017   0.0       0.0272      0.270000
# 4          0.429  0.4530   0.0    -7.746   1.0       0.0459      0.554000
# 5          0.517  0.6750   6.0    -5.382   1.0       0.0357      0.459000
# 6          0.675  0.6090   1.0    -7.905   1.0       0.0940      0.284000
# 7          0.847  0.6220   1.0    -6.747   0.0       0.0903      0.119000
# 8          0.801  0.8060  11.0    -5.206   1.0       0.0381      0.382000
# 9          0.671  0.8450  11.0    -4.930   0.0       0.0480      0.020700
# 10         0.770  0.5800   0.0    -8.393   1.0       0.2470      0.519000
# 11         0.483  0.4080   5.0    -9.243   0.0       0.0502      0.508000
# 12         0.570  0.6700   1.0    -6.519   1.0       0.0274      0.426000
# 13         0.576  0.6830   7.0    -5.103   1.0       0.1180      0.410000
# 14         0.672  0.1590   9.0    -8.760   0.0       0.0343      0.962000
# 15         0.627  0.8790   9.0    -3.446   1.0       0.0955      0.001930
# 16         0.624  0.7660   8.0    -3.805   1.0       0.0359      0.199000
# 17         0.755  0.6800   8.0    -6.150   0.0       0.0862      0.206000
# 18         0.829  0.4360   3.0    -8.205   1.0       0.3270      0.150000
# 19         0.504  0.7710   6.0    -4.231   1.0       0.0319      0.012300
# 20         0.637  0.6430   4.0    -6.571   1.0       0.0519      0.130000
# 21         0.451  0.6320   4.0    -3.843   1.0       0.0475      0.600000
# 22         0.678  0.2640  10.0   -12.384   1.0       0.0622      0.753000
# 23         0.753  0.7260   6.0    -3.209   0.0       0.0326      0.243000
# 24         0.644  0.7350   8.0    -5.747   1.0       0.0391      0.052100
# 25         0.302  0.5840   1.0    -6.242   1.0       0.0630      0.385000
# 26         0.667  0.6130   8.0    -7.147   1.0       0.0313      0.121000
# 27         0.444  0.0911   0.0   -17.665   1.0       0.0307      0.959000
# 28         0.739  0.4130   1.0    -6.709   1.0       0.0282      0.470000
# 29         0.715  0.6200   1.0    -6.005   0.0       0.0484      0.417000
# 30         0.789  0.7630   1.0    -6.169   1.0       0.1990      0.123000
# 31         0.731  0.7440   1.0    -5.770   0.0       0.1740      0.109000
# 32         0.670  0.5550   1.0    -9.120   0.0       0.0908      0.038200
# 33         0.527  0.2520   7.0    -8.024   1.0       0.0362      0.839000
# 34         0.927  0.6190   5.0    -4.441   0.0       0.0539      0.018600
# 35         0.753  0.6690   7.0    -4.914   0.0       0.1040      0.037800
# 36         0.508  0.4300   2.0    -9.475   0.0       0.0335      0.830000
# 37         0.911  0.5360   4.0    -7.884   0.0       0.2820      0.008970
# 38         0.459  0.8610   0.0    -3.762   0.0       0.0529      0.047400
# 39         0.646  0.7360   5.0    -7.118   0.0       0.0449      0.216000
# 40         0.841  0.7380   7.0    -7.455   0.0       0.3070      0.520000
# 41         0.453  0.9870  11.0    -3.012   0.0       0.2510      0.000164
# 42         0.532  0.4890   4.0    -7.419   1.0       0.0311      0.149000
# 43         0.475  0.5740   7.0    -7.512   1.0       0.2180      0.000791
# 44         0.680  0.2460   4.0   -14.112   1.0       0.0580      0.783000
# 45         0.741  0.5090  10.0   -12.639   1.0       0.0532      0.076100
# 46         0.564  0.6120   0.0    -5.018   1.0       0.0248      0.382000
# 47         0.647  0.6420   2.0    -7.687   1.0       0.0785      0.177000
# 48         0.610  0.5710   2.0    -5.649   1.0       0.0782      0.008630
# 49         0.570  0.5570   2.0   -12.055   1.0       0.1050      0.143000
#
#     instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0           0.000004    0.1120    0.726   99.974     230480.0             4.0
# 1           0.000000    0.1100    0.392  143.008     201800.0             4.0
# 2           0.000006    0.2650    0.625  128.027     240760.0             4.0
# 3           0.020800    0.2630    0.936  108.501     215326.0             4.0
# 4           0.000002    0.1020    0.155   77.639     227196.0             4.0
# 5           0.000000    0.1510    0.518  203.853     163855.0             4.0
# 6           0.268000    0.1120    0.057  119.973     300000.0             4.0
# 7           0.000000    0.2850    0.220  130.001     125040.0             4.0
# 8           0.000669    0.1140    0.802  106.999     239318.0             4.0
# 9           0.000000    0.3290    0.775  110.056     176579.0             4.0
# 10          0.000127    0.2330    0.753  144.072     109750.0             4.0
# 11          0.000000    0.2590    0.105   88.880     310491.0             3.0
# 12          0.000000    0.1080    0.593  140.924     178723.0             4.0
# 13          0.000000    0.0819    0.433  151.566     214056.0             4.0
# 14          0.000018    0.1060    0.117  113.218     210827.0             4.0
# 15          0.000007    0.0647    0.748  129.979     184784.0             4.0
# 16          0.000009    0.1560    0.370  172.080     181621.0             4.0
# 17          0.000046    0.1220    0.373  123.031     265360.0             4.0
# 18          0.000000    0.0954    0.693  143.031     223204.0             4.0
# 19          0.000019    0.0780    0.555  157.985     197400.0             4.0
# 20          0.000002    0.1420    0.533   97.008     200690.0             4.0
# 21          0.000000    0.1390    0.455  147.060     190461.0             4.0
# 22          0.000000    0.3020    0.528  121.722     187244.0             4.0
# 23          0.000000    0.1140    0.827  111.026     131872.0             1.0
# 24          0.144000    0.1610    0.418   88.980     153947.0             4.0
# 25          0.000052    0.0890    0.159  199.804     170825.0             4.0
# 26          0.000000    0.1130    0.681  112.046     213817.0             4.0
# 27          0.000001    0.0980    0.142   78.403     222370.0             4.0
# 28          0.000025    0.1310    0.649  139.921     208853.0             4.0
# 29          0.000000    0.0822    0.172   97.950     221520.0             4.0
# 30          0.000022    0.1320    0.272  140.107     126857.0             4.0
# 31          0.000000    0.1230    0.727  171.859     223344.0             4.0
# 32          0.000006    0.4140    0.160  156.937     146808.0             4.0
# 33          0.000000    0.1000    0.157   82.069     231907.0             4.0
# 34          0.000000    0.1040    0.817  117.995     211582.0             4.0
# 35          0.000000    0.1220    0.584  140.948     247469.0             4.0
# 36          0.000441    0.0930    0.324  130.090     212954.0             4.0
# 37          0.000004    0.1110    0.584  146.014     203813.0             4.0
# 38          0.000005    0.1070    0.333  145.842     180034.0             4.0
# 39          0.000000    0.4150    0.873  140.098     212878.0             3.0
# 40          0.000000    0.0892    0.484  169.918     172798.0             4.0
# 41          0.000000    0.0776    0.206  154.080     268919.0             4.0
# 42          0.000000    0.2370    0.320  139.807     229627.0             4.0
# 43          0.810000    0.0670    0.194  158.689     175099.0             5.0
# 44          0.000000    0.1060    0.388  110.230     171693.0             4.0
# 45          0.000003    0.1140    0.345  152.078     202224.0             4.0
# 46          0.000000    0.1100    0.146   83.030     237493.0             3.0
# 47          0.000000    0.0948    0.219   87.523     120895.0             4.0
# 48          0.000000    0.1310    0.747  105.010     171655.0             4.0
# 49          0.000000    0.0926    0.301   83.224     153129.0             4.0

# %%
features.to_csv('features_only.csv')

# %% [markdown]
# ## Scaling features

# %%
features.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   2393.000000  2393.000000  2393.000000  2393.000000  2393.000000
# mean       0.654972     0.682573     5.246135    -6.050226     0.611366
# std        0.143712     0.176478     3.594404     2.677144     0.487542
# min        0.162000     0.009370     0.000000   -34.840000     0.000000
# 25%        0.562000     0.576000     2.000000    -7.054000     0.000000
# 50%        0.665000     0.706000     5.000000    -5.613000     1.000000
# 75%        0.757000     0.816000     8.000000    -4.381000     1.000000
# max        0.975000     0.988000    11.000000    -0.276000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  2393.000000   2393.000000       2393.000000  2393.000000  2393.000000
# mean      0.097543      0.175801          0.029112     0.174655     0.530481
# std       0.092555      0.228216          0.136587     0.135874     0.231151
# min       0.022500      0.000013          0.000000     0.021000     0.000010
# 25%       0.038000      0.018500          0.000000     0.090700     0.354000
# 50%       0.057300      0.076100          0.000000     0.120000     0.536000
# 75%       0.113000      0.237000          0.000064     0.222000     0.717000
# max       0.591000      0.995000          0.991000     0.971000     0.974000
#
#              tempo    duration_ms  time_signature
# count  2393.000000    2393.000000     2393.000000
# mean    121.136483  223321.473046        3.974091
# std      27.848254   44775.877261        0.252408
# min      50.141000   62253.000000        1.000000
# 25%      99.050000  197547.000000        4.000000
# 50%     120.040000  220291.000000        4.000000
# 75%     138.015000  245000.000000        4.000000
# max     210.857000  688453.000000        5.000000

# %%
list(features.columns)
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature']

# %%
scaler = StandardScaler()
scaler.fit(features)
filename = "./songs_scaler.pickle" # Path with filename
with open(filename, "wb") as file:
        pickle.dump(scaler,file)

features_scaled = scaler.transform(features)



features_scaled_df = pd.DataFrame(features_scaled, columns = features.columns)

# %%
features_scaled_df.head(3)
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      1.454791 -0.717367 -0.903297 -0.610021 -1.254240     1.042370
# 1     -0.667945 -0.745705 -0.068491 -0.441149  0.797295     0.372360
# 2     -0.723624  0.671201  0.209777  0.366596  0.797295    -0.726673
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0      0.347109         -0.213159 -0.461220  0.846027 -0.760080     0.159908
# 1     -0.152522         -0.213187 -0.475943 -0.599216  0.785546    -0.480749
# 2     -0.713511         -0.213143  0.665060  0.408992  0.247483     0.389544
#
#    time_signature
# 0        0.102668
# 1        0.102668
# 2        0.102668

# %%
features_scaled_df.to_csv('features_only_numeric.csv')

# %%
features_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  2.393000e+03  2.393000e+03  2.393000e+03  2.393000e+03  2.393000e+03
# mean  -1.068932e-16 -2.137864e-16  1.336165e-17 -8.907765e-18  5.938510e-17
# std    1.000209e+00  1.000209e+00  1.000209e+00  1.000209e+00  1.000209e+00
# min   -3.430983e+00 -3.815459e+00 -1.459833e+00 -1.075616e+01 -1.254240e+00
# 25%   -6.470658e-01 -6.040142e-01 -9.032965e-01 -3.750203e-01 -1.254240e+00
# 50%    6.979278e-02  1.327766e-01 -6.849146e-02  1.633524e-01  7.972955e-01
# 75%    7.100937e-01  7.562150e-01  7.663136e-01  6.236404e-01  7.972955e-01
# max    2.227328e+00  1.731046e+00  1.601119e+00  2.157311e+00  7.972955e-01
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  2.393000e+03  2.393000e+03      2.393000e+03  2.393000e+03
# mean  -1.781553e-16 -8.907765e-17     -9.650079e-18  2.167556e-16
# std    1.000209e+00  1.000209e+00      1.000209e+00  1.000209e+00
# min   -8.109643e-01 -7.704302e-01     -2.131873e-01 -1.131100e+00
# 25%   -6.434618e-01 -6.894063e-01     -2.131873e-01 -6.180162e-01
# 50%   -4.348942e-01 -4.369612e-01     -2.131873e-01 -4.023299e-01
# 75%    1.670342e-01  2.682197e-01     -2.127164e-01  3.485237e-01
# max    5.332596e+00  3.590327e+00      7.043794e+00  5.862145e+00
#
#             valence         tempo   duration_ms  time_signature
# count  2.393000e+03  2.393000e+03  2.393000e+03    2.393000e+03
# mean   6.176051e-16  2.019093e-16 -3.325566e-16   -6.829287e-17
# std    1.000209e+00  1.000209e+00  1.000209e+00    1.000209e+00
# min   -2.295386e+00 -2.549902e+00 -3.597967e+00   -1.178534e+01
# 25%   -7.636448e-01 -7.932669e-01 -5.757533e-01    1.026684e-01
# 50%    2.388261e-02 -3.938171e-02 -6.769508e-02    1.026684e-01
# 75%    8.070829e-01  6.062156e-01  4.842576e-01    1.026684e-01
# max    1.919141e+00  3.222438e+00  1.039016e+01    4.065339e+00

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# When we create an instance of PCA, we can specify how many principal components we want to extract.
# However, as we don't know beforehand how much variance it will explain each principal component it's
# allways better to not set the option "n_components" to a given integer number.

pca = PCA()
pca.fit(features_scaled_df)
principal_components = pca.transform(features_scaled_df)
principal_components_df = pd.DataFrame(principal_components, columns=['PCA_'+ str(i) for i in range(1,features_scaled_df.shape[1]+1)])
principal_components_df.head()
# Out:
#       PCA_1     PCA_2     PCA_3     PCA_4     PCA_5     PCA_6     PCA_7  \
# 0  0.149442 -2.291443 -0.570646 -0.029856  1.079605  0.252891  0.250975
# 1  0.834009  0.661565 -0.039238 -0.638074 -0.036820  0.920871 -0.677748
# 2 -0.913617  1.227355 -0.042173 -0.089479 -0.449133 -0.453721  0.149601
# 3 -1.061876 -0.711208 -0.176099 -0.073551 -0.774499 -0.699600  1.111297
# 4  2.861587  1.141353 -1.999040  0.049371  0.137282 -0.386465  0.421235
#
#       PCA_8     PCA_9    PCA_10    PCA_11    PCA_12    PCA_13
# 0 -1.048253  0.150435 -0.264345  0.229729  0.224841 -0.016145
# 1  0.227240 -0.405213  0.308296 -0.297133  0.426402 -0.239358
# 2  0.699256  0.256766 -0.357394 -0.038991  0.485959 -0.052679
# 3 -1.262973  0.339408 -1.131749  1.141240  0.377862  0.433185
# 4 -0.409364 -0.848611  0.416150  0.936383 -0.189874 -0.118735

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.20553422 0.11197232 0.08646415 0.08606486 0.0819277  0.07728864
#  0.07537957 0.06613583 0.06534895 0.05235072 0.04526144 0.03044826
#  0.01582334]

# %%
cumulated_explained_variance_ratio = [sum(pca.explained_variance_ratio_[0:i+1]) for i,value in enumerate(pca.explained_variance_ratio_)]
cumulated_explained_variance_ratio
# Out:
# [0.20553421873113686,
#  0.31750653642739657,
#  0.40397068484785403,
#  0.4900355490815448,
#  0.5719632485986647,
#  0.6492518891781666,
#  0.7246314567681477,
#  0.79076728896443,
#  0.8561162358910787,
#  0.9084669556056593,
#  0.9537283996431611,
#  0.9841766641749338,
#  1.0000000000000002]

# %% [markdown]
# This method is not appropriate to reduce the columns because we would need to many and that is not what we want.

# %% [markdown]
# ### ISOMAP

# %%
from sklearn.manifold import Isomap

iso = Isomap(n_neighbors=12, n_components=2)
iso.fit(features_scaled_df)
filename = "./isomap.pickle" # Path with filename
with open(filename, "wb") as file:
        pickle.dump(iso,file)


X_isomap_transformed = iso.transform(features_scaled_df)
X_isomap_transformed_df = pd.DataFrame(X_isomap_transformed, columns=["ISO_1","ISO_2"])
X_isomap_transformed_df.head()
# Out:
#       ISO_1     ISO_2
# 0  5.605747  0.129472
# 1 -3.157980  0.540552
# 2 -3.715833 -0.750687
# 3  6.493931 -1.895372
# 4 -2.343562  3.084319

# %%
fig, ax = plt.subplots()
ax.scatter(X_isomap_transformed_df['ISO_1'],X_isomap_transformed_df['ISO_2'])
ax.set_xlabel("ISO_1")
ax.set_ylabel("ISO_2")
plt.show()

# %% [markdown]
# ### TSNE

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, learning_rate=100, init='random', perplexity=40, random_state=12)

X_tsne_transformed = tsne.fit_transform(features_scaled_df)
# use pickle to save the tnse. tnse.transform(user_song_audio_features_scaled)
filename = "./tsne_features.pickle" # Path with filename
with open(filename, "wb") as file:
        pickle.dump(tsne,file)

X_tsne_transformed_df = pd.DataFrame(X_tsne_transformed, columns=["TSNE_1","TSNE_2"])
X_tsne_transformed_df.head()
# Out:
#       TSNE_1     TSNE_2
# 0  12.057183  30.787363
# 1 -10.278848 -15.751392
# 2  31.176271 -17.586489
# 3   1.761075  48.901566
# 4 -25.752190 -14.395313

# %%
from mpl_toolkits.mplot3d import Axes3D
fig, ax = plt.subplots()
ax.scatter(X_tsne_transformed_df['TSNE_1'],X_tsne_transformed_df['TSNE_2'])
ax.set_xlabel("TSNE_1")
ax.set_ylabel("TSNE_2")
plt.show()

# %% [markdown]
# # Clustering

# %%
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### K-MEAN

# %%
kmeans = KMeans(n_clusters=5, random_state=1234)
kmeans.fit(X_tsne_transformed_df)

filename = "./kmeans_features.pickle" # Path with filename
with open(filename, "wb") as file:
        pickle.dump(kmeans,file)
# save the kmeans with pickle
# Out:
# c:\Users\chech\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
clusters = kmeans.predict(X_tsne_transformed_df)
#clusters
pd.Series(clusters).value_counts().sort_index() # Number of wines in each cluster
# Out:
# 0    441
# 1    420
# 2    788
# 3    441
# 4    303
# dtype: int64

# %%
concat_nhs_hs["cluster"] = clusters
concat_nhs_hs
# Out:
#                       Title                                Artist  \
# 0        Paint The Town Red                              Doja Cat
# 1                    Snooze                                   SZA
# 2                  Fast Car                            Luke Combs
# 3              Cruel Summer                          Taylor Swift
# 4     I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# ...                     ...                                   ...
# 2289             La Bachata                         Manuel Turizo
# 2290      Until I Found You                       Stephen Sanchez
# 2291          Made You Look                        Meghan Trainor
# 2292          Midnight Rain                          Taylor Swift
# 2293               Die Hard                        Kendrick Lamar
#
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.864   0.556   2.0    -7.683   0.0       0.1940       0.25500
# 1            0.559   0.551   5.0    -7.231   1.0       0.1320       0.14100
# 2            0.551   0.801   6.0    -5.069   1.0       0.0303       0.01300
# 3            0.666   0.871   1.0    -6.017   0.0       0.0272       0.27000
# 4            0.429   0.453   0.0    -7.746   1.0       0.0459       0.55400
# ...            ...     ...   ...       ...   ...          ...           ...
# 2289         0.775   0.736   1.0    -8.072   0.0       0.2470       0.31900
# 2290         0.935   0.807  11.0    -3.838   0.0       0.1140       0.05140
# 2291         0.751   0.468   5.0    -9.251   1.0       0.3130       0.15000
# 2292         0.773   0.422   1.0    -4.572   0.0       0.1870       0.00783
# 2293         0.376   0.657   7.0    -4.658   1.0       0.0768       0.08580
#
#       instrumentalness  ...    tempo            type                      id  \
# 0             0.000004  ...   99.974  audio_features  56y1jOTK0XSvJzVv9vHQBK
# 1             0.000000  ...  143.008  audio_features  4iZ4pt7kvcaH6Yo8UoZ4s2
# 2             0.000006  ...  128.027  audio_features  1mMLMZYXkMueg65jRRWG1l
# 3             0.020800  ...  108.501  audio_features  2EGaDf0cPX789H3LNeB03D
# 4             0.000002  ...   77.639  audio_features  4KULAymBBJcPRpk1yO4dOG
# ...                ...  ...      ...             ...                     ...
# 2289          0.001160  ...  100.988  audio_features  2g6tReTlM2Akp41g0HaeXN
# 2290          0.000000  ...  106.017  audio_features  6Zu3aw7FfjAF9WA0fA81Oq
# 2291          0.000015  ...  150.009  audio_features  1DlLCrqbalAshwtMexNkGR
# 2292          0.006930  ...   77.502  audio_features  3XOalgusokruzA5ZBA2Qcb
# 2293          0.000000  ...   80.565  audio_features  1r8ZCjfrQxoy2wVaBUbpwg
#
#                                        uri  \
# 0     spotify:track:56y1jOTK0XSvJzVv9vHQBK
# 1     spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 2     spotify:track:1mMLMZYXkMueg65jRRWG1l
# 3     spotify:track:2EGaDf0cPX789H3LNeB03D
# 4     spotify:track:4KULAymBBJcPRpk1yO4dOG
# ...                                    ...
# 2289  spotify:track:2g6tReTlM2Akp41g0HaeXN
# 2290  spotify:track:6Zu3aw7FfjAF9WA0fA81Oq
# 2291  spotify:track:1DlLCrqbalAshwtMexNkGR
# 2292  spotify:track:3XOalgusokruzA5ZBA2Qcb
# 2293  spotify:track:1r8ZCjfrQxoy2wVaBUbpwg
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/56y1jOTK0XSv...
# 1     https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 2     https://api.spotify.com/v1/tracks/1mMLMZYXkMue...
# 3     https://api.spotify.com/v1/tracks/2EGaDf0cPX78...
# 4     https://api.spotify.com/v1/tracks/4KULAymBBJcP...
# ...                                                 ...
# 2289  https://api.spotify.com/v1/tracks/2g6tReTlM2Ak...
# 2290  https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF...
# 2291  https://api.spotify.com/v1/tracks/1DlLCrqbalAs...
# 2292  https://api.spotify.com/v1/tracks/3XOalgusokru...
# 2293  https://api.spotify.com/v1/tracks/1r8ZCjfrQxoy...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/56y1...    230480.0
# 1     https://api.spotify.com/v1/audio-analysis/4iZ4...    201800.0
# 2     https://api.spotify.com/v1/audio-analysis/1mML...    240760.0
# 3     https://api.spotify.com/v1/audio-analysis/2EGa...    215326.0
# 4     https://api.spotify.com/v1/audio-analysis/4KUL...    227196.0
# ...                                                 ...         ...
# 2289  https://api.spotify.com/v1/audio-analysis/2g6t...    239027.0
# 2290  https://api.spotify.com/v1/audio-analysis/6Zu3...    173182.0
# 2291  https://api.spotify.com/v1/audio-analysis/1DlL...    184842.0
# 2292  https://api.spotify.com/v1/audio-analysis/3XOa...    136267.0
# 2293  https://api.spotify.com/v1/audio-analysis/1r8Z...    164782.0
#
#      time_signature  Hot  cluster
# 0               4.0    Y        2
# 1               4.0    Y        3
# 2               4.0    Y        1
# 3               4.0    Y        2
# 4               4.0    Y        4
# ...             ...  ...      ...
# 2289            4.0    N        2
# 2290            4.0    N        2
# 2291            4.0    N        1
# 2292            1.0    N        4
# 2293            4.0    N        3
#
# [2393 rows x 22 columns]

# %%
concat_nhs_hs.to_csv('concat_nhs_hs.csv')

# %%
features["cluster"] = clusters
features.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.864   0.556  2.0    -7.683   0.0       0.1940         0.255
# 1         0.559   0.551  5.0    -7.231   1.0       0.1320         0.141
# 2         0.551   0.801  6.0    -5.069   1.0       0.0303         0.013
# 3         0.666   0.871  1.0    -6.017   0.0       0.0272         0.270
# 4         0.429   0.453  0.0    -7.746   1.0       0.0459         0.554
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000004     0.112    0.726   99.974     230480.0             4.0
# 1          0.000000     0.110    0.392  143.008     201800.0             4.0
# 2          0.000006     0.265    0.625  128.027     240760.0             4.0
# 3          0.020800     0.263    0.936  108.501     215326.0             4.0
# 4          0.000002     0.102    0.155   77.639     227196.0             4.0
#
#    cluster
# 0        2
# 1        3
# 2        1
# 3        2
# 4        4

# %%
# user_scaled = scaler.transform(x_user)
# user_cluster = kmeans.predict(x_user_scaled)
# features[(features['cluster'] == "N") & (features['cluster'] == clusters)].sample(5)

# %%
kmeans.inertia_
# Out:
# 543145.1875

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='TSNE_1', y='TSNE_2',hue=clusters, data=X_tsne_transformed_df, palette='viridis', s=50)
plt.title('KMeans Clustering on t-SNE Transformed Data')
plt.show()

# %%
print("The Silhouette score of the model is: ",round(silhouette_score(X_tsne_transformed_df, kmeans.fit_predict(X_tsne_transformed_df)),2))
print("The Calinksi-Harabasz score of the model is: ",round(calinski_harabasz_score(X_tsne_transformed_df, kmeans.fit_predict(X_tsne_transformed_df)),2))
# Out:
# c:\Users\chech\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# The Silhouette score of the model is:  0.43
# c:\Users\chech\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# The Calinksi-Harabasz score of the model is:  2736.85

# %% [markdown]
# ### DBSCAN

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import euclidean
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from kneed import KneeLocator
import matplotlib.pyplot as plt
import seaborn as sns
import colorcet as cc
import time
import pickle
from dbcv import *

# %%
dbscan = DBSCAN(eps=0.5, min_samples=4) # Epsilon=distance, MinPoints=min_samples
values = dbscan.fit_predict(X_tsne_transformed_df)

# %%
X_tsne_transformed_df1 = X_tsne_transformed_df.copy()
X_tsne_transformed_df1
# Out:
#          TSNE_1     TSNE_2
# 0     12.057183  30.787363
# 1    -10.278848 -15.751392
# 2     31.176271 -17.586489
# 3      1.761075  48.901566
# 4    -25.752190 -14.395313
# ...         ...        ...
# 2388 -19.627802  20.720440
# 2389   6.180340  52.441338
# 2390  14.964701   9.427775
# 2391 -51.648697 -23.390873
# 2392   1.446291 -28.528542
#
# [2393 rows x 2 columns]

# %%
X_tsne_transformed_df1['dbscan_clusters'] = values
X_tsne_transformed_df1
# Out:
#          TSNE_1     TSNE_2  dbscan_clusters
# 0     12.057183  30.787363               -1
# 1    -10.278848 -15.751392               -1
# 2     31.176271 -17.586489               -1
# 3      1.761075  48.901566               -1
# 4    -25.752190 -14.395313               -1
# ...         ...        ...              ...
# 2388 -19.627802  20.720440               -1
# 2389   6.180340  52.441338               -1
# 2390  14.964701   9.427775               -1
# 2391 -51.648697 -23.390873                0
# 2392   1.446291 -28.528542               -1
#
# [2393 rows x 3 columns]

# %%
X_tsne_transformed_df1['dbscan_clusters'].value_counts().sort_index()
# Out:
# -1    2373
#  0       4
#  1       4
#  2       4
#  3       4
#  4       4
# Name: dbscan_clusters, dtype: int64

# %%
dbscan_clusters = np.unique(values)
dbscan_clusters
# Out:
# array([-1,  0,  1,  2,  3,  4], dtype=int64)

# %%
[dbscan_cluster for dbscan_cluster in list(dbscan_clusters) if cluster != -1]
# Out:
# [-1, 0, 1, 2, 3, 4]

# %%
X_tsne_transformed_df1['dbscan_clusters'] = values
# Creating a pallette of hihg contrast colors with as many color as cluster labels
custom_palette = sns.color_palette(cc.glasbey, n_colors=dbscan_clusters.size)
# Modifiying the palette to set the color "black=(0.,0.,0.)" to the label "-1" #(R,G,B)
custom_palette = [color if cluster != -1 else (0.,0.,0.) for cluster, color in zip(dbscan_clusters,custom_palette)]
sns.scatterplot(X_tsne_transformed_df1, x="TSNE_1", y="TSNE_2", hue="dbscan_clusters", palette=custom_palette);
plt.show()

# %% [markdown]
# DBSCAN is not good clustering method for our database

# %% [markdown]
# ### HDBSCAN

# %%
# min_samples = 2 * # columns = 2 * 2 = 4
# For every point get what is the distance between each point and the 4-Nearest-Neigbourh
# Sort these distances in descending order, and plot them
# Look where the curve starts to flatten to get the optimal epsilon

# %%
from sklearn.cluster import HDBSCAN

# %% [markdown]
#     Metrics of clustering:
#     - what is a cluster for you?
#     (DBCV for DBSCAN and HDBSCAN)
#     KMeans Silhoette score

# %%
X_tsne_transformed_df2 = X_tsne_transformed_df.copy()
X_tsne_transformed_df2
# Out:
#          TSNE_1     TSNE_2
# 0     12.057183  30.787363
# 1    -10.278848 -15.751392
# 2     31.176271 -17.586489
# 3      1.761075  48.901566
# 4    -25.752190 -14.395313
# ...         ...        ...
# 2388 -19.627802  20.720440
# 2389   6.180340  52.441338
# 2390  14.964701   9.427775
# 2391 -51.648697 -23.390873
# 2392   1.446291 -28.528542
#
# [2393 rows x 2 columns]

# %%
# distance between user_song and all the other songs
# pick the smallest distance (which is not noise)
# user_cluster = cluster of the song with the smalles distance
# scipy.spatial.distance_matrix(user_tsne_coordinates, songs_tsne_ccordinates_without_tnoise)
# numpy_array with the distances between the user_song and all the other songs.
# sort them and get the smallest.

# %%
import scipy.spatial

# %%
from scipy.spatial import distance_matrix

# %%
from scipy.spatial import distance_matrix

# Assuming X_tsne_transformed_df2 is the data for clustering

# Fit HDBSCAN model

model = HDBSCAN(min_cluster_size=8, min_samples=8)
labels = model.fit_predict(X_isomap_transformed_df)

hdbscan = "./hdbscan_features.pickle" # Path with filename
with open(filename, "wb") as file:
        pickle.dump(hdbscan,file)

# Get the Coordinates of the user's song in the ISOMAP space
user_isomap_coordinates = iso.transform(features_scaled_df)
print(user_isomap_coordinates)
display(X_isomap_transformed_df.head())

# Calculate pairwise distances between user's song and all other songs
distances = distance_matrix(user_isomap_coordinates, X_isomap_transformed_df[['ISO_1','ISO_2']])

# Find the index of the nearest point (smallest distance)
nearest_index = np.argmin(distances)

# Get the cluster label of the nearest point
nearest_cluster = labels[nearest_index]

print(f"The nearest cluster to the user's song is {nearest_cluster}")
# Out:
# [[  5.60574702   0.12947177]
#  [ -3.15798037   0.54055239]
#  [ -3.71583333  -0.75068741]
#  ...
#  [ -2.03535345   0.95864896]
#  [  2.55111221 -17.80124512]
#  [ -4.74595228   0.51360372]]
#       ISO_1     ISO_2
# 0  5.605747  0.129472
# 1 -3.157980  0.540552
# 2 -3.715833 -0.750687
# 3  6.493931 -1.895372
# 4 -2.343562  3.084319
# The nearest cluster to the user's song is 6

# %%
hdbscan_clusters = np.unique(values1)
hdbscan_clusters
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
X_isomap_transformed_df['hdbscan_clusters'] = labels
# Creating a pallette of hihg contrast colors with as many color as cluster labels
custom_palette = sns.color_palette(cc.glasbey, n_colors=hdbscan_clusters.size)
# Modifiying the palette to set the color "black=(0.,0.,0.)" to the label "-1" #(R,G,B)
custom_palette = [color if cluster != -1 else (0.,0.,0.) for cluster, color in zip(hdbscan_clusters,custom_palette)]
sns.scatterplot(X_isomap_transformed_df, x="ISO_1", y="ISO_2", hue="hdbscan_clusters", palette=custom_palette);
plt.show()
# Out:
# C:\Users\chech\AppData\Local\Temp\ipykernel_19076\3683820906.py:6: UserWarning:
# The palette list has fewer values (4) than needed (9) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(X_isomap_transformed_df, x="ISO_1", y="ISO_2", hue="hdbscan_clusters", palette=custom_palette);

# %%
X_isomap_transformed_df
# Out:
#          ISO_1      ISO_2  hdbscan_clusters
# 0     5.605747   0.129472                 6
# 1    -3.157980   0.540552                 2
# 2    -3.715833  -0.750687                 2
# 3     6.493931  -1.895372                 6
# 4    -2.343562   3.084319                 2
# ...        ...        ...               ...
# 2388  5.461597   2.383432                 6
# 2389  6.775567  -1.100790                 6
# 2390 -2.035353   0.958649                 2
# 2391  2.551112 -17.801245                -1
# 2392 -4.745952   0.513604                 2
#
# [2393 rows x 3 columns]
